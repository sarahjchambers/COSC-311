# %% [markdown]
# # Python Skill Review (LAB 1)
#
# ## Author: Sarah Chambers
#
# ### 1. Write a program to print out the first 20 numbers of the Triangular Number Sequence.
# Calculate  and  output  the  sum  of  even  numbers  and  sum  of  odd  numbers, respectively, in the first 20 numbers

# %%
sum_even = 0
sum_odd = 0

for n in range(1,21):
    i = (n * (n + 1))/2
    make_int = int(i)
    print(f"The first 20 numbers in the triangular sequence are: {make_int}")
    
    if (make_int % 2 == 0):
        sum_even += make_int
    else:
        sum_odd += make_int

print("The even sum is ", str(sum_even))
print("The odd sum is", str(sum_odd))
# Out:
# The first 20 numbers in the triangular sequence are: 1
# The first 20 numbers in the triangular sequence are: 3
# The first 20 numbers in the triangular sequence are: 6
# The first 20 numbers in the triangular sequence are: 10
# The first 20 numbers in the triangular sequence are: 15
# The first 20 numbers in the triangular sequence are: 21
# The first 20 numbers in the triangular sequence are: 28
# The first 20 numbers in the triangular sequence are: 36
# The first 20 numbers in the triangular sequence are: 45
# The first 20 numbers in the triangular sequence are: 55
# The first 20 numbers in the triangular sequence are: 66
# The first 20 numbers in the triangular sequence are: 78
# The first 20 numbers in the triangular sequence are: 91
# The first 20 numbers in the triangular sequence are: 105
# The first 20 numbers in the triangular sequence are: 120
# The first 20 numbers in the triangular sequence are: 136
# The first 20 numbers in the triangular sequence are: 153
# ...

# %% [markdown]
# ### 2. Write a program to define a function to take three inputs (outlook, humidity, and wind).
# It uses a nested if-statement to express the following decision tree model. This function returns either
# True or False to indicate whether a user will play tennis or not, in the main function, ask user
# input the values for outlook, humidity, and wind, respectively; call the above function to get result, then output whether the user should play tennis or not.

# %%
def weather_choices(outlook, humidity, wind):
    
    if outlook == 'Sunny':
        if humidity == 'Normal':
            return True
        else:
            return False
    elif outlook == 'Rain':
        if wind == 'Strong':
            return False
        else:
            return True
    elif outlook == 'Overcast':
        return True
    else:
        return False


def main():
    
    outlook = input("What is the outlook today? (Sunny/Rain/Overcast): ")
    humidity = input("What is the humidity today? (High/Normal): ")
    wind = input("What is the wind today? (Strong/Weak): ")
    
    tennis_choice = weather_choices(outlook, humidity, wind)
    
    if tennis_choice == True:
        print("You can play tennis today!")
    else:
        print("You can not play tennis today!")

main()

# %% [markdown]
# ### 3. Define a function to take a side length, L, as input.
# It draws an octagon of length L using asterisks (*).
# n the main function, ask user input the side length; you need to do input validation check so that the
# input side length must be greater or equal to 2 (otherwise, ask user input again till it is valid)

# %%
def draw_octagon(L):
    space = L - 1
    og_l = L - 1

    for i in range(L):

        spaces = ((space) * ' ')
        asterisks = (L) * '*'
        row = spaces + asterisks + spaces

        space -= 1
        L += 2
        
        print(row)
    
    for i in range(og_l):
        
        spaces = ((space) * ' ')
        asterisks = ((L - 2) * '*')
        row = spaces + asterisks + spaces
        
        print(row)
        
    for i in range(og_l + 1):

        spaces = ((space + 1) * ' ')
        asterisks = (L - 2) * '*'
        row = spaces + asterisks + spaces

        space += 1
        L -= 2
        
        print(row)
        

def main():
    while True:
        L = int(input("Enter the side length of the octagon (must be >= 2): "))
        
        if L >= 2:
            break
        else:
            print("Invalid side length. Please try again.")
    
    draw_octagon(L)

main()
# Out:
# Enter the side length of the octagon (must be >= 2): 10
#          **********
#         ************
#        **************
#       ****************
#      ******************
#     ********************
#    **********************
#   ************************
#  **************************
# ****************************
# ****************************
# ****************************
# ****************************
# ****************************
# ****************************
# ****************************
# ****************************
# ****************************
# ****************************
# ****************************
#  **************************
#   ************************
#    **********************
#     ********************
#      ******************
#       ****************
#        **************
#         ************
#          **********

# %% [markdown]
# ### 4. Write a program to roll the two dice n times, then calculate the probability for each value, as shown in the above figure (right).
# Keep 2 digits after the decimal point for the probability results.
# Test your program using n = 100 and n = 100,000 respectively, and show the probability for each value.

# %%
import random
import math


def roll_dice(number_roll):
    
    sum_count = [0] * 13
    
    for i in range(number_roll):
        d1 = random.randint(1,6)
        d2 = random.randint(1,6)
        sum_rolls = d1 + d2
        
        sum_count[sum_rolls] += 1
    
    for i in range(2, 13):
        prob_rolls = sum_count[i]/ number_roll
        print(f"The probablity of rolling a {i} is {prob_rolls: .2f}")
    

number_roll = int(input("How many times do you want to roll your die? "))
roll_dice(number_roll)

# Test the program when n = 100
print("\nWhen n = 100:")
roll_dice(100)

# Test the program when n = 100,000
print("\nWhen n = 100,000:")
roll_dice(100000)
# Out:
# How many times do you want to roll your die? 5
# The probablity of rolling a 2 is  0.00
# The probablity of rolling a 3 is  0.00
# The probablity of rolling a 4 is  0.00
# The probablity of rolling a 5 is  0.00
# The probablity of rolling a 6 is  0.20
# The probablity of rolling a 7 is  0.20
# The probablity of rolling a 8 is  0.40
# The probablity of rolling a 9 is  0.00
# The probablity of rolling a 10 is  0.20
# The probablity of rolling a 11 is  0.00
# The probablity of rolling a 12 is  0.00
#
# When n = 100:
# The probablity of rolling a 2 is  0.04
# The probablity of rolling a 3 is  0.05
# The probablity of rolling a 4 is  0.12
# The probablity of rolling a 5 is  0.08
# The probablity of rolling a 6 is  0.18
# The probablity of rolling a 7 is  0.18
# The probablity of rolling a 8 is  0.06
# The probablity of rolling a 9 is  0.08
# The probablity of rolling a 10 is  0.09
# The probablity of rolling a 11 is  0.08
# The probablity of rolling a 12 is  0.04
#
# When n = 100,000:
# ...

# %% [markdown]
# ### 5. Write a program to define a function to take three inputs (outlook, humidity, and wind).
# It uses a nested if-statement to express the following decision tree model. This function
# returns either True or False to indicate whether a user will play tennis or not,
# in the main function, ask user input the values for outlook, humidity, and wind,
# respectively; call the above function to get result, then output whether the user
# should play tennis or not.

# %%
def weather_choices(outlook, humidity, wind):
    if outlook == 'Sunny':
        if humidity == 'Normal':
            return True
        else:
            return False
    elif outlook == 'Rain':
        if wind == 'Strong':
            return False
        else:
            return True
    elif outlook == 'Overcast':
        return True
    else:
        return False


def main():
    
    outlook = input("What is the outlook today? (Sunny/Rain/Overcast): ")
    humidity = input("What is the humidity today? (High/Normal): ")
    wind = input("What is the wind today? (Strong/Weak): ")
    
    tennis_choice = weather_choices(outlook, humidity, wind)
    
    if tennis_choice == True:
        print("You can play tennis today!")
    else:
        print("You can not play tennis today!")

main()
